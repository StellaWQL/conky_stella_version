# %%
import pandas as pd
import subprocess

# %%
def check_unwanted_strings(x):
    unwanted_strings = ["No album found", "No artist found", "No price available"]
    return any([str == x for str in unwanted_strings])
    
df = pd.read_csv('vinyl_records.csv')
mask = df.applymap(check_unwanted_strings)

df_cleaned = df[~mask.any(axis=1)]
df_cleaned
# Out:
#                                                   Album  \
# 6     Live At The Orpheum Theatre - April 12, 1994 E...
# 7     Live At The Orpheum Theatre - April 12, 1994 E...
# 8                                    Grace Exclusive LP
# 9                        Psychocandy Exclusive LP (Gum)
# 10    Future Past LP (Color) With Autographed Art Print
# ...                                                 ...
# 2544                                         Nation 2LP
# 2545                                          Faith 2LP
# 2546                       Gifts From The Holy Ghost LP
# 2547                             Bobby Tarantino III LP
# 2548                                  Sounds LP (Color)
#
#                         Artist    Price  \
# 6                    Pearl Jam  $124.99
# 7                    Pearl Jam  $124.99
# 8                 Jeff Buckley  $104.99
# 9     The Jesus And Mary Chain   $41.99
# 10                 Duran Duran   $35.99
# ...                        ...      ...
# 2544                 Sepultura   $29.99
# 2545                 Pop Smoke   $36.99
# 2546                   Dorothy   $19.99
# 2547                     Logic   $29.99
# 2548               Spare Snare   $36.99
#
#                                               Image URL
# 6     //www.newburycomics.com/cdn/shop/products/Pear...
# 7     //www.newburycomics.com/cdn/shop/products/Pear...
# 8     //www.newburycomics.com/cdn/shop/products/Jeff...
# 9     //www.newburycomics.com/cdn/shop/products/The-...
# 10    //www.newburycomics.com/cdn/shop/products/Dura...
# ...                                                 ...
# 2544  //www.newburycomics.com/cdn/shop/products/2593...
# 2545  //www.newburycomics.com/cdn/shop/products/Pop_...
# 2546  //www.newburycomics.com/cdn/shop/products/Doro...
# 2547  //www.newburycomics.com/cdn/shop/products/Logi...
# 2548  //www.newburycomics.com/cdn/shop/products/Spar...
#
# [2543 rows x 4 columns]

# %%
def get_random_number():
    command = "dd if=/dev/urandom bs=4 count=1 2>/dev/null | od -An -tu4"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    random_number = int(result.stdout.strip())
    return random_number

# %%
random_indexes = [get_random_number() % len(df_cleaned) for _ in range(3)]
selected_records = df.iloc[random_indexes]
for index, row in selected_records.iterrows():
    print(f"{row['Album']}|{row['Artist']}")
# Out:
# I Won't Care How You Remember Me Exclusive LP|Tigers Jaw
# Infest The Rats' Nest Exclusive LP|King Gizzard And The Lizard Wizard
# Terminal Velocity Exclusive 2LP (With Autographed Postcard)|John Petrucci
